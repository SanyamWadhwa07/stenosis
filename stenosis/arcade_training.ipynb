# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 976.9/976.9 kB 51.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 50.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 29.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# !pwd
# Out:
# /content

# %%
import os
os.chdir('./drive/MyDrive/arcade')

# %%
from ultralytics import YOLO

# Load a model
#model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)

best_model_path = './runs/detect/train9/weights/last.pt'
model = YOLO(best_model_path)  # load a custom model

# Train the model
results = model.train(data="./stenosis/data_bbox.yaml", epochs=100, imgsz=512)
# Out:
# Ultralytics 8.3.99 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# ## Inferencing

# %%
# !pwd
# Out:
# /content

# %%
import os

# %%
os.chdir('./drive/MyDrive/arcade/')

# %%
# !pwd
# Out:
# /content/drive/MyDrive/arcade

# %%
best_model_path = './runs/detect/train9/weights/best.pt'

# %%
from ultralytics import YOLO

# Load the trained model
model = YOLO(best_model_path)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
results = model('./stenosis/train/images/100.png', save=True, conf=0.1)
# Out:
# image 1/1 /content/drive/MyDrive/arcade/stenosis/train/images/100.png: 512x512 1 stenosis, 25.5ms
# Speed: 1.5ms preprocess, 25.5ms inference, 2.7ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs/detect/predict

# %%
results = model('./stenosis/test/images/70.png', save=True, conf=0.5)
# Out:
# image 1/1 /content/drive/MyDrive/arcade/stenosis/test/images/70.png: 512x512 2 stenosiss, 25.5ms
# Speed: 2.0ms preprocess, 25.5ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs/detect/predict
